# %%
import zipfile

with zipfile.ZipFile('/home/iai/Desktop/Jeewon/Capstone/cosmetic.zip') as target_file:
  target_file.extractall('/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/')

# %%
import yaml

data = {
    'train' : '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/train/images',
    'val' : '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images',
    'test' : '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/test/images',
    'names' : ['blusher', 'brush', 'concealer', 'cream', 'eyelashes', 'foundation', 'highlighter', 'liner', 'mascara', 'powder', 'primer', 'shadow'],
    'nc' : 12
}

with open('/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/cosmetic_data.yaml','w') as f:
  yaml.dump(data, f)

with open('/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/cosmetic_data.yaml', 'r') as f:
  cosmetic_yaml = yaml.safe_load(f)
  display(cosmetic_yaml)
# Out:
# {'names': ['blusher',
#   'brush',
#   'concealer',
#   'cream',
#   'eyelashes',
#   'foundation',
#   'highlighter',
#   'liner',
#   'mascara',
#   'powder',
#   'primer',
#   'shadow'],
#  'nc': 12,
#  'test': '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/test/images',
#  'train': '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/train/images',
#  'val': '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images'}

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.86 🚀 Python-3.8.13 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24268MiB)
# Setup complete ✅ (32 CPUs, 125.0 GB RAM, 466.3/1832.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# ...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data = '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/cosmetic_data.yaml', epochs = 100, patience = 30, batch = 32, imgsz = 416)
# Out:
# Ultralytics YOLOv8.0.86 🚀 Python-3.8.13 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24268MiB)
# ...

# %%
results = model.predict(source = '/home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images', save = True)
# Out:
# image 1/26 /home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images/--------------2022-06-15---13-20-22_png.rf.8b0662e53eb8f1513143148d3bc4ec4d.jpg: 256x416 1 eyelashes, 3.0ms
# image 2/26 /home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images/--------------2022-06-15---13-21-52_png.rf.309e20694677da58354502814ed79ab0.jpg: 256x416 1 shadow, 2.6ms
# image 3/26 /home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images/--------------2022-06-15---13-22-42_png.rf.86a1d3c86d27097588616fd873843f34.jpg: 256x416 2 brushs, 2.6ms
# image 4/26 /home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images/--------------2022-06-15---13-26-02_png.rf.de54bbbbc17110f9ed63ca977d44c661.jpg: 256x416 (no detections), 2.6ms
# image 5/26 /home/iai/Desktop/Jeewon/Capstone/cosmetic_data/valid/images/--------------2022-06-15---13-26-28_png.rf.43f2b214409e430730a4506993b080c0.jpg: 256x416 1 mascara, 2.6ms
# ...
